# %%
"pk.eyJ1IjoiYXJhbGRoYWZlZXJpIiwiYSI6ImNrZzBtMHY5YTJpd3EycXM4aWJuenIzeXUifQ.H3dQr4j_qqb-H2Z8KICinw"
# Out:
# 'pk.eyJ1IjoiYXJhbGRoYWZlZXJpIiwiYSI6ImNrZzBtMHY5YTJpd3EycXM4aWJuenIzeXUifQ.H3dQr4j_qqb-H2Z8KICinw'

# %%
'kajlkafsdljhdsfaljkfhljk3398339p83293unw'
# Out:
# 'kajlkafsdljhdsfaljkfhljk3398339p83293unw'

# %%
import requests
import json
import pandas as pd 
import numpy as np

# %%
df_deaths= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv') 
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
df_deaths
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 267            NaN             Vietnam  14.058324  108.277199        0
# 268            NaN  West Bank and Gaza  31.952200   35.233200        0
# 269            NaN               Yemen  15.552727   48.516388        0
# 270            NaN              Zambia -13.133897   27.849332        0
# 271            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  1/3/21  1/4/21  1/5/21  \
# ...

# %%
today_date = df_recovered.columns[-1]

# %%
today_date
# Out:
# '1/12/21'

# %%
df_recovered[today_date]
# Out:
# 0       44608
# 1       38421
# 2       69608
# 3        7930
# 4       15512
#         ...
# 252      1361
# 253    133599
# 254      1416
# 255     21074
# 256     13396
# Name: 1/12/21, Length: 257, dtype: int64

# %%
df_deaths[today_date]
# Out:
# 0      2301
# 1      1252
# 2      2816
# 3        86
# 4       422
#        ...
# 267      35
# 268    1630
# 269     612
# 270     495
# 271     551
# Name: 1/12/21, Length: 272, dtype: int64

# %%
df_confirmed[today_date]
# Out:
# 0       53584
# 1       64627
# 2      102641
# 3        8682
# 4       18343
#         ...
# 267      1520
# 268    148968
# 269      2107
# 270     29757
# 271     23239
# Name: 1/12/21, Length: 272, dtype: int64

# %%
#  Creating new df with lat, log, country_name, today total deaths,  today total recovered, today total confirmed

# %%
new_df = df_deaths[['Country/Region']].copy()

# %%
data = [df_deaths['Country/Region'], df_confirmed['Lat'], df_confirmed['Long'], df_confirmed[today_date], df_recovered[today_date], df_deaths[today_date]]

# %%
headers = ['Country', 'Lat', 'Long','Confirmed', 'Recovered', 'Deaths' ]

# %%
new_df = pd.concat(data, axis=1, keys=headers)

# %%
new_df
# Out:
#                 Country        Lat        Long  Confirmed  Recovered  Deaths
# 0           Afghanistan  33.939110   67.709953      53584    44608.0    2301
# 1               Albania  41.153300   20.168300      64627    38421.0    1252
# 2               Algeria  28.033900    1.659600     102641    69608.0    2816
# 3               Andorra  42.506300    1.521800       8682     7930.0      86
# 4                Angola -11.202700   17.873900      18343    15512.0     422
# ..                  ...        ...         ...        ...        ...     ...
# 267             Vietnam  14.058324  108.277199       1520        NaN      35
# 268  West Bank and Gaza  31.952200   35.233200     148968        NaN    1630
# 269               Yemen  15.552727   48.516388       2107        NaN     612
# 270              Zambia -13.133897   27.849332      29757        NaN     495
# 271            Zimbabwe -19.015438   29.154857      23239        NaN     551
#
# [272 rows x 6 columns]
