# %%
import pandas as pd
df_deaths= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv') 
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
today_date = df_deaths.columns[-1]

# %%
today_date
# Out:
# '10/5/20'

# %%
sum(list(df_deaths[today_date]))
# Out:
# 1043945

# %%
import plotly.graph_objects as go
df_confirmed
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/26/20  9/27/20  \
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scattergeo(
        lon = df_confirmed['Long'],
        lat = df_confirmed['Lat'],
        text = df_confirmed[today_date],
        marker = dict(
            size = df_confirmed[today_date]/10000,
            color = "purple",
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
            name ="Confirmed"))
fig.add_trace(go.Scattergeo(
        lon = df_deaths['Long'],
        lat = df_deaths['Lat'],
        text = df_deaths[today_date],
        marker = dict(
            size = df_deaths[today_date]/10000,
            color = "red",
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
            name ="Deaths"))
fig.add_trace(go.Scattergeo(
        lon = df_recovered['Long'],
        lat = df_recovered['Lat'],
        text = df_recovered[today_date],
        marker = dict(
            size = df_recovered[today_date]/10000,
            color = "green",
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
            name ="Recovered"))

fig.add_trace(go.Scattergeo(
        lon = df_recovered['Long'],
        lat = df_recovered['Lat'],
        text = df_recovered["Country/Region"],
        marker = dict(
            size = df_recovered[today_date]/10000,
            color = "beige",
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
            name ="Country Name"))


fig.update_layout(
        showlegend = True,
        geo = dict(
            landcolor = 'rgb(217, 217, 217)',
        )
    )


fig.write_html("templates/map.html")

# %%
# Line plots 
import plotly.express as px
import numpy as np

# %%
days = df_recovered.columns[4:]
days
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '9/26/20', '9/27/20', '9/28/20', '9/29/20', '9/30/20', '10/1/20',
#        '10/2/20', '10/3/20', '10/4/20', '10/5/20'],
#       dtype='object', length=258)

# %%
day_zero = days[0]
last_day = days[-1]
number_of_days = len(days)

# %%
day_zero, last_day, number_of_days
# Out:
# ('1/22/20', '10/5/20', 258)

# %%
time = np.arange(0,number_of_days + 8,1)

# %%
del df_deaths["time"]

# %%
df_deaths["Days"] = time

# %%
len(list(df_recovered.iloc[1]))
# Out:
# 262

# %%
for i in range(0, len(time)):
    print(list(df_deaths.iloc[i])[1])
    print(list(df_deaths.iloc[i])[4:] + [0])
# Out:
# Afghanistan
# 260
# Albania
# 260
# Algeria
# 260
# Andorra
# 260
# Angola
# 260
# Antigua and Barbuda
# 260
# Argentina
# 260
# Armenia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Australia
# 260
# Austria
# 260
# Azerbaijan
# 260
# Bahamas
# 260
# Bahrain
# 260
# Bangladesh
# 260
# Barbados
# 260
# Belarus
# 260
# Belgium
# 260
# Belize
# 260
# Benin
# 260
# Bhutan
# 260
# Bolivia
# 260
# Bosnia and Herzegovina
# 260
# Botswana
# 260
# Brazil
# 260
# Brunei
# 260
# Bulgaria
# 260
# Burkina Faso
# 260
# Burma
# 260
# Burundi
# 260
# Cabo Verde
# 260
# Cambodia
# 260
# Cameroon
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Canada
# 260
# Central African Republic
# 260
# Chad
# 260
# Chile
# 260
# China
# 260
# China
# 260
# China
# 260
# ...

# %%
fig_line = go.Figure()

# %%
import plotly.express as px
import math
for i in range(0, len(time)):
    fig_line.add_trace(
        go.Scatter(x=time[7:], y =df_deaths.iloc[i][4:],
                   name=df_deaths.iloc[i][1] + f"(</b> {str(df_deaths.iloc[i][2])},{str(df_deaths.iloc[i][2])})"))
fig_line.write_html("templates/line_deaths.html")

# %%
fig_bar = go.Figure()
for i in range(0, len(time)):
    fig_bar.add_trace(
        go.Bar(x=["Region", "Country"], y =[0,sum(list(df_deaths.iloc[i][4:]))],
                   name=df_deaths.iloc[i][1] + f"(</b> {str(df_deaths.iloc[i][2])},{str(df_deaths.iloc[i][2])})"))
fig_bar.write_html("templates/bar_deaths.html")
